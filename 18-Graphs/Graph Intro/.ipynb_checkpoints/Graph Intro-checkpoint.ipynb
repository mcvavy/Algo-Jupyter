# %% [markdown]
# > **Directed Graphs**
#
#     In the example on the right, the graph can be traversed from vertex A to B, but not from vertex B to A.
#
#    ![image.png](attachment:image.png)
#
#    1. **Cyclic**: When there's a node such that traversal leads to the same node
#        ![image-4.png](attachment:image-4.png)
#        <br>
#
#    2. **Acyclic**: No path will return to the same node
#
#
#    <br>
#    <br>
#
# > **Undirected Graphs**
#
#     In the example on the left, the graph can be traversed from node A to B as well as from node B to A.
#
#    ![image-2.png](attachment:image-2.png)
#
#    <br>
#
#    ![image-3.png](attachment:image-3.png)
#
#
# <br>
# <br>
#
# > **Labelling**
#
# ![image-5.png](attachment:image-5.png)
#
#
#
# <br>
#
# > **Weighted Graph**
#
#
# ![image-6.png](attachment:image-6.png)
#
# <br>
#
# > **Sparsity Graph**
#
#
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# ### Representation Of Graph

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
# <br>
#
# ![image-3.png](attachment:image-3.png)
#
# <br>
#
# ![image-4.png](attachment:image-4.png)
