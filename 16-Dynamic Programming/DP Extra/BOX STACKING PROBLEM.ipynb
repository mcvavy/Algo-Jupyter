# %% [markdown]
# >**Box Stacking Problem**
#
# Create a stack of boxes as tall as possible
#
# - [Box Stacking Problem](https://www.youtube.com/watch?v=kLucR6-Q0GA&list=PLEJXowNB4kPxBwaXtRO1qFLpCzF75DYrS&index=25&ab_channel=TECHDOSE)

# %% [markdown]
# Solution:
# <br>
#
# ![image-11.png](attachment:image-11.png)
#
# <br>
#
# ![image-13.png](attachment:image-13.png)
#
# <br>
#
# ![image-14.png](attachment:image-14.png)

# %%
import numpy
from typing import List
from collections import namedtuple

Max = namedtuple("Max", ("val", "index"))

class Solution:
    def lengthOfLIS(self, nums: List[int]) -> int:
        n = len(nums);
        dp = [1] * n
        
        for i in range(1, n):
            for j in range(i):
                if nums[j] < nums[i]:
                    dp[i] = max(dp[i], dp[j] + 1)
        return max(dp)
        """
        for i in range(1, n):
            for j in range(i):
                if nums[j] < nums[i]:
                    current_max = Max(-1, -1)
                    if dp[j] + 1 > dp[i]:
                        current_max = Max(dp[j] + 1, j)
                        dp[i] = current_max.val
                    else:
                        current_max = Max(dp[i], i)
                        dp[i] = current_max.val
                    
                    if current_max.val > max_length.val:
                        max_length = current_max
        return max_length.val if max_length != Max(-1, -1) else 1
        """
    

import unittest
class LISTest(unittest.TestCase):
    def test_lis_test1(self):
        result = Solution().lengthOfLIS([10,9,2,5,3,7,101,18])
        self.assertEqual(result, 4)
        
    def test_lis_test2(self):
        result = Solution().lengthOfLIS([0,1,0,3,2,3])
        self.assertEqual(result, 4)
        
    def test_lis_test3(self):
        result = Solution().lengthOfLIS([7,7,7,7,7,7,7])
        self.assertEqual(result, 1)
        
unittest.main(argv=[''], verbosity=2, exit=False)
# Out:
# test_lis_test1 (__main__.LISTest) ... ok
# test_lis_test2 (__main__.LISTest) ... ok
# test_lis_test3 (__main__.LISTest) ... ok
#
# ----------------------------------------------------------------------
# Ran 3 tests in 0.004s
#
# OK
