# %% [markdown]
# >**Russian Doll Envelopes**
#
# - [Russian Doll Envelopes](https://www.youtube.com/watch?v=3fF1r5nhQX4&list=PLEJXowNB4kPxBwaXtRO1qFLpCzF75DYrS&index=26&ab_channel=TECHDOSE)
#
# <br>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Solution:
# <br>
#
# ![image-16.png](attachment:image-16.png)
#
# <br>
#
# ![image-17.png](attachment:image-17.png)
#
# <br>
#
# ![image-18.png](attachment:image-18.png)
#
# <br>
#
# ![image-19.png](attachment:image-19.png)

# %%
import numpy
from typing import List
from collections import namedtuple

class Solution:
    def maxEnvelopes(self, e: List[List[int]]) -> int:
        if len(e) == 0:
            return 0
        
        e.sort(key=lambda x: (x[0], x[1]))
        dp = [1] * len(e)
        maxCount = 1
        for i in range(1, len(e)):
            for j in range(i):
                if e[i][0] > e[j][0] and e[i][1] > e[j][1]:
                    dp[i] = max(dp[i], dp[j] + 1)
                    maxCount = max(maxCount, dp[i])
        return maxCount
    

import unittest
class MaxEnvelopeTest(unittest.TestCase):
    def test_lis_test1(self):
        result = Solution().maxEnvelopes([[5,4],[6,4],[6,7],[2,3]])
        self.assertEqual(result, 3)
        
unittest.main(argv=[''], verbosity=2, exit=False)
# Out:
# test_lis_test1 (__main__.MaxEnvelopeTest) ... ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# OK
