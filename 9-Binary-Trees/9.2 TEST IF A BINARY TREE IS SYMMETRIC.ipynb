# %% [markdown]
# > **Write a program that checks whether a binary tree is symmetric.**
#
# _Hint:The definition of symmetry is recursive._
#
# ![image-2.png](attachment:image-2.png)
#
# - [Is Tree Symmetric Explanation](https://www.youtube.com/watch?v=XV7Sg2hJO3Q&ab_channel=BackToBackSWE)

# %%
# Time complexity: O(n)  | Space complexity O(h), h - height of tree
def is_symmetric(tree: BinaryTreeNode) -> bool:
    def check_symmetry(leftSub: BinaryTreeNode, rightSub: BinaryTreeNode)-> bool:
        if not leftSub and not rightSub:
            return True
        elif leftSub and rightSub:
            return leftSub.data == rightSub.data and \
        check_symmetry(leftSub.left, rightSub.right) and \
        check_symmetry(leftSub.right, rightSub.left)
            
        return False
    return tree is None or check_symmetry(tree.left, tree.right)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8ab1c72ec16d> in <module>
# ----> 1 def is_balanced_binary_tree(tree: BinaryTreeNode) -> bool:
#       2     # TODO - you fill in here.
#       3     return True
#
# NameError: name 'BinaryTreeNode' is not defined
