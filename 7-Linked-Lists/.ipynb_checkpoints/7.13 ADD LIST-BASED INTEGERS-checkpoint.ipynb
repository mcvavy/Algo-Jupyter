# %% [markdown]
# > **Write a program which takes two singly linked lists of digits, and returns the list corresponding to the sum of the integers they represent. The least significant digit comes first.**
#
# _Hint: First, solve the problem assuming no pair of corresponding digits sum to more than 9._
#
# ![image-7.png](attachment:image-7.png)

# %%
# Time complexity: O(m+n) | Space complexity: O(max(n,m))
def add_two_numbers(L1: ListNode, L2: ListNode) -> Optional[ListNode]:
    place_iter = dummy_head = ListNode()
    carry = 0
    while L1 or L2 or carry:
        val = carry + (L1.data if L1 else 0) + (L2.data if L2 else 0)
        L1 = L1.next if L1 else None
        L2 = L2.next if L2 else None
        place_iter.next = ListNode(val % 10)
        carry = val // 10; place_iter = place_iter.next
    return dummy_head.next
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0d0834e079e3> in <module>
# ----> 1 def is_linked_list_a_palindrome(L: ListNode) -> bool:
#       2     # TODO - you fill in here.
#       3     return True
#
# NameError: name 'ListNode' is not defined
